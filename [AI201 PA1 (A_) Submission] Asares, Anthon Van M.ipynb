# %%
from __future__ import annotations
import copy
from abc import ABC, abstractmethod
from itertools import chain
from typing import Callable, Literal, List, TypedDict

# Define custom types here
State = List[List[str]]
class OperationDict(TypedDict):
    operator: Callable
    state: State


class Node:
    """ Implements a node. """
    
    def __init__(
        self, 
        state: State, 
        parent_node: Node = None,
        operator: Callable = None, 
        depth: int = 0,
        path_cost: int = 0,
        f_value: int = 0,
        h_value: int = 0,
        p_value: int = 0,
        s_value: int = 0
    ) -> None:
        """ 
        Since we're not using matrix packages like numpy, we'll just implement
        the matrix with list. So the format will be something like
        [
            [1, 2, 3],
            [4, 5, 6],
            [7, 8, 9]
        ]

        As for the operators, it's best to just define them outside the class
        to be more flexible as we might want a different way to play the game.
        """
        self._state = state
        self._parent_node = parent_node
        self._operator = operator
        self._depth = depth
        self._path_cost = path_cost
        self._f_value = f_value
        self._p_value = p_value
        self._h_value = h_value
        self._s_value = s_value

    @property
    def state(self) -> State:
        return self._state

    @property
    def parent_node(self) -> Node:
        return self._parent_node
    
    @parent_node.setter
    def parent_node(self, node: Node) -> None:
        self._parent_node = node

    @property
    def operator(self) -> Callable:
        return self._operator
    
    @operator.setter
    def operator(self, operator: Operator) -> None:
        self._operator = operator

    @property
    def depth(self) -> int:
        return self._depth
    
    @depth.setter
    def depth(self, depth: int) -> None:
        self._depth = depth

    @property
    def path_cost(self) -> int:
        return self._path_cost
    
    @path_cost.setter
    def path_cost(self, pc: int) -> None:
        self._path_cost = pc

    @property
    def h_value(self) -> int:
        return self._h_value

    @h_value.setter
    def h_value(self, h: int) -> None:
        self._h_value = h
    
    @property
    def f_value(self) -> int:
        return self._f_value
    
    @f_value.setter
    def f_value(self, amt: int) -> None:
        self._f_value = amt

    @property
    def s_value(self) -> int:
        return self._s_value
    
    @s_value.setter
    def s_value(self, amt: int) -> None:
        self._s_value = amt

    @property
    def p_value(self) -> int:
        return self._p_value
    
    @p_value.setter
    def p_value(self, amt: int) -> None:
        self._p_value = amt

    def __eq__(self, other: Node) -> bool:
        return self.state == other.state
    
    def __lt__(self, other: Node) -> bool:
        """ 
        If the f-values are equal, try to see which node
        has the lesser heuristic point
        """
        if self.f_value == other.f_value:
            return self.h_value < other.h_value
        return self.f_value < other.f_value
    
    def __ge__(self, other: Node) -> bool:
        return self.f_value >= other.f_value
    
    def __repr__(self) -> str:
        return f'{self.state}'

    def __str__(self) -> str:
        return f'{self.state}'


class Problem:
    """
    This is the class that I envision will take in the initial and the goal states,
    as well as handling the state transitions. Meaning I will put the successor fn
    as a method in this class as generate_successors.
    """
    def __init__(
        self, 
        initial_state: State = [],
        goal_state: State = [],
        operators: List[Operator] = [],
        heuristic: HeuristicsABC = None
    ) -> None:
        self._initial_state = initial_state
        self._goal_state = goal_state
        self._operators = operators
        self._heuristic = heuristic

    @classmethod
    def from_file(cls, filepath: str, operators: List[Operator]):
        """ Class method that inititalizes the search problem """
        goal_state = []
        initial_state = [] 

        # Determine where to append. Points to the correct list.
        current_list = initial_state

        with open(filepath, 'r') as file:
            for line in file:
                row = line.strip().split(' ')
                if row[0] == 'start':
                    current_list = initial_state
                elif row[0] == 'goal':
                    current_list = goal_state
                else:
                    current_list.append(row)

        return cls(initial_state, goal_state, operators)
    
    @property
    def initial_state(self) -> State:
        return self._initial_state

    @property
    def goal_state(self) -> State:
        return self._goal_state

    @property
    def operators(self):
        return self._operators

    @property
    def heuristic(self):
        return self._heuristic
    
    @heuristic.setter
    def heuristic(self, heuristic: HeuristicsABC):
        self._heuristic = heuristic
    
    def is_goal(self, curr_state: State) -> bool:
        """ Returns True if we finally reached goal """
        return curr_state == self._goal_state


class HeuristicsABC(ABC):

    def manhattan_distance(self, curr_state: State, goal_state: State) -> int:
        """ 
        Really bad implementation but it's just so that we could print P(s).
        Just return 0 for all except Nilsson Sequence Score
        """
        return 0
    
    def sequence_score(self, curr_state: State, goal_state: State) -> int:
        """ Same case as manhattan distance """
        return 0
    
    @property
    @abstractmethod
    def identifier(self) -> str:
        return 'general heuristic'

    @abstractmethod
    def compute_heuristic(self, curr_state: State, goal_state: State) -> int:
        pass


class ManhattanDistance(HeuristicsABC):
    """
    For two points (a_1, a_2) and (g_1, g_2), the manhattan distance is just
    md = abs(b_1 - g_1) + abs(g_2 - a_2) for every element not in their
    proper place.

    This is easier if we just concatenate all the rows and operate on modulo 3.
    We'll use itertools.chain to simplify flattening our State type
    """

    @property
    def identifier(self) -> str:
        return 'ManhattanDistance'

    def compute_heuristic(self, curr_state: State, goal_state: State) -> int:
        flattened_curr_state = list(chain.from_iterable(curr_state))
        flattened_goal_state = list(chain.from_iterable(goal_state))
        total = 0
        for index, tile in enumerate(flattened_curr_state):
            if tile == '*':
                continue
            curr_state_q, curr_state_r = divmod(index, 3)
            goal_state_q, goal_state_r = divmod(flattened_goal_state.index(tile), 3)
            total += abs(curr_state_q - goal_state_q) + abs(curr_state_r - goal_state_r)
        
        return total
    

class NumOfTilesInWrongPosition(HeuristicsABC):
    """
    Just check if every corresponding index has the same element.
    We again neglect the '*' element.
    We'll use the flattened version of the matrix again as the code
    has less loops.
    """

    @property
    def identifier(self) -> str:
        return 'NumOfTilesWrong'

    def compute_heuristic(self, curr_state: State, goal_state: State) -> int:
        flattened_curr_state = list(chain.from_iterable(curr_state))
        flattened_goal_state = list(chain.from_iterable(goal_state))
        total = 0
        for i in range(len(flattened_curr_state)):
            if flattened_curr_state[i] == '*':
                continue
            
            if flattened_curr_state[i] != flattened_goal_state[i]:
                total += 1

        return total
    

class NilssonSequenceScore(ManhattanDistance):
    """
    h(n) = P(n) + 3 S(n) where P(n) is the Manhattan distance of each tile from its 
    goal position and S(n) is a sequence score
    """

    @property
    def identifier(self) -> str:
        return 'NilssonSequenceScore'

    def manhattan_distance(self, curr_state: List[Node], goal_state: List[Node]) -> int:
        return super().compute_heuristic(curr_state, goal_state)
    
    def N(self, tile: str, curr_state: State) -> int:
        """ 
        N(tile) is the current square where the tile currently lies.

        We'll try to map in the format given in stackoverflow
        +---+---+---+
        | 0 | 1 | 2 |
        +---+---+---+
        | 7 | 8 | 3 |
        +---+---+---+
        | 6 | 5 | 4 |
        +---+---+---+
        """
        ordering = {
            (0, 0): 0, (0, 1): 1, (0, 2): 2,
            (1, 2): 3, (2, 2): 4, (2, 1): 5,
            (2, 0): 6, (1, 0): 7, (1, 1): 8
        }
        for index, row in enumerate(curr_state):
            if tile in row:
                return ordering[(index, row.index(tile))]
            else:
                continue
        
    def next_tile(self, tile: str) -> str:
        """ Returns the next value of the tile """
        q, r = divmod(int(tile) + 1, 9)
        return str(q + r)

    def sequence_score(self, curr_state: State, goal_state: State) -> int:
        score = 0
        for tile in list(chain.from_iterable(curr_state)):
            if tile == '*':
                continue

            # Not going to be multiplying by 3 just yet. Will do it in the final NSS
            if self.N(tile, curr_state) == 8:
                score += 1
            elif self.N(self.next_tile(tile), curr_state) != (self.N(tile, curr_state) + 1) % 8:
                score += 2

        return score

    def compute_heuristic(self, curr_state: State, goal_state: State) -> int:
        manhattan_distance = super().compute_heuristic(curr_state, goal_state)
        return manhattan_distance +  3 * self.sequence_score(curr_state, goal_state) 


class Operator:
    def __init__(self, move: Literal['up', 'down', 'left', 'right']) -> None:
        self._move = move

    def do_move(self, state: State, star_row: int, star_col: int) -> State:
        """ Detect where the '*' is and exchange position """
        move_map = {
            'up': (star_row - 1, star_col),
            'down': (star_row + 1, star_col),
            'left': (star_row, star_col - 1),
            'right': (star_row, star_col + 1)
        }
        
        moved_row, moved_col = move_map[self._move]
        # Check if anything is out of bound
        is_legal = (
            0 <= moved_row < len(state) 
            and 0 <= moved_col < len(state[0])
        )
        if not is_legal:
            raise IndexError(f'Move {self._move} is illegal')

        state[star_row][star_col], state[moved_row][moved_col] = (
            state[moved_row][moved_col],
            state[star_row][star_col]
        )
        return state
    
    def __repr__(self) -> str:
        return self._move

    def __str__(self) -> str:
        return f'Move {self._move.capitalize()}'


class AstarAlgorithm:
    """ 
    Implements the algorithm based on the pseudocode in the slids. 
    Steps 1 - 8 should be numbered accordingly and are in the run_algo method
    """

    def __init__(self, problem: Problem):
        self._problem = problem

    @property
    def problem(self) -> Problem:
        return self._problem
    
    def compute_fs(self, node: Node) -> int:
        """ Just h + g """
        h = self.problem.heuristic.compute_heuristic(node.state, problem.goal_state)
        g = node.path_cost
        return h + g

    def generate_successors(self, n: Node) -> List[Node]:
        """
        This should be handling #5 of the A* pseudo code by generating all the
        successors and computing each node's f(s)
        """
        successor_nodes: List[Node] = []
        for operator in self.problem.operators:
            for index, items in enumerate(n.state):
                if '*' not in items:
                    continue
                row, col = index, items.index('*')
                try:
                    new_state = operator.do_move(copy.deepcopy(n.state), row, col)
                    if n.parent_node and new_state == n.parent_node.state:
                        continue
                    successor_node = Node(new_state, n, operator, n.depth + 1, n.path_cost + 1)
                    successor_node.f_value = self.compute_fs(successor_node)
                    successor_node.h_value = self.problem.heuristic.compute_heuristic(
                        new_state, self.problem.goal_state)
                    successor_node.s_value = self.problem.heuristic.sequence_score(
                        new_state, self.problem.goal_state)
                    successor_node.p_value = self.problem.heuristic.manhattan_distance(
                        new_state, self.problem.goal_state)
                    successor_nodes.append(successor_node)
                except IndexError as e:
                    continue

        return successor_nodes

    def run_algo(self) -> List[Node]:
        """ Method that runs the pseudocode. """

        # Step 1
        s = Node(
            self.problem.initial_state, 
            None, 
            None, 
            0, 
            0, 
        )
        s.f_value = self.compute_fs(s)
        s.h_value = self.problem.heuristic.compute_heuristic(
            s.state, self.problem.goal_state)
        s.s_value = self.problem.heuristic.sequence_score(
            s.state, self.problem.goal_state)
        s.p_value = self.problem.heuristic.manhattan_distance(
            s.state, self.problem.goal_state)
        OPEN = [s]
        CLOSED = []
        nodes_generated = 0
        unique_nodes_generated = 0
        nodes_expanded = 0

        counter = 0
        print('\nDisplay relevant costs...')
        print('+----------------------------------------------------------+')
        while counter < 1000000: # Just setting a hard limit of 1M iterations before stopping
            # Step 2
            if not len(OPEN):
                raise ValueError('OPEN MUST NOT BE EMPTY!!!')

            # Step 3
            n = min(OPEN)
            print_string = f'state = {n}; f(n) = {n.f_value}; g(n) = {n.path_cost}; h(n) = {n.h_value}'
            if self.problem.heuristic.identifier == 'NilssonSequenceScore':
                print_string += f'; p(n) = {n.p_value}; s(n) = {n.s_value}'
            print_string += f'; Number of nodes generated: {nodes_generated}'
            print(print_string)

            OPEN.remove(n)
            CLOSED.append(n)

            # Step 4
            if self.problem.is_goal(n.state):
                solution_path = []
                while n:
                    solution_path.append(n)
                    n = n.parent_node

                print(f'\nSummary for A* using {self.problem.heuristic.identifier}')
                print('+----------------------------------------------------------+')
                print(f'Nodes generated: {nodes_generated}; Unique nodes generated: {unique_nodes_generated}; Nodes expanded: {nodes_expanded}')
                print(f'Open List: {len(OPEN)}; Closed List: {len(CLOSED)}')
                return list(reversed(solution_path))
            
            # Step 5
            n_successors = self.generate_successors(n)
            nodes_expanded += 1
            if not len(n_successors):
                continue

            for successor in n_successors:
                nodes_generated += 1
                # Step 6
                if successor not in OPEN and successor not in CLOSED:
                    unique_nodes_generated += 1
                    OPEN.append(successor)
                    continue

                list_to_use = OPEN if successor in OPEN else CLOSED
                prev_successor = list_to_use[list_to_use.index(successor)]
                
                if successor >= prev_successor:
                    continue
                
                # Step 7
                prev_successor.depth = successor.depth
                prev_successor.path_cost = successor.path_cost
                prev_successor.operator = successor.operator
                prev_successor.parent_node = successor.parent_node
                prev_successor.f_value = successor.f_value
                prev_successor.s_value = successor.s_value
                prev_successor.p_value = successor.p_value
                prev_successor.h_value = successor.h_value

                if successor in CLOSED:
                    CLOSED.remove(prev_successor)
                    OPEN.append(successor)

                # Step 8 - since we're just continuing the loop
                counter += 1


def print_matrices(*matrices, chunk_size=10):
    # Format each matrix into a string with rows
    formatted_matrices = [
        [" ".join(row) for row in matrix] for matrix in matrices
    ]
    
    # Iterate over the list in chunks
    for start_index in range(0, len(formatted_matrices), chunk_size):
        end_index = min(start_index + chunk_size, len(formatted_matrices))  # Ensure we don't go out of bounds
        chunk = formatted_matrices[start_index:end_index]
        
        print(f'Moves {start_index} to {end_index - 1}')
        
        # Combine rows with arrows for the middle row
        combined_rows = []
        for i, row_group in enumerate(zip(*chunk)):
            if i == 1:  # Middle row (index 1 for 3x3 matrices)
                combined_rows.append(" -> ".join(row_group))
            else:
                combined_rows.append("    ".join(row_group))
        
        print("\n".join(combined_rows))
        # print("\n")


if __name__ == "__main__":
    # Modify input file below
    directory = 'astar_in.txt'
    problem = Problem.from_file(
        directory,
        [
            Operator('up'),
            Operator('down'),
            Operator('left'),
            Operator('right')
        ], 
    )

    # Initialize the heuristics
    nss = NilssonSequenceScore()
    md = ManhattanDistance()
    nw = NumOfTilesInWrongPosition()
    heuristics = [nw, md, nss]
    algo = AstarAlgorithm(problem)
    for heur in heuristics:
        problem.heuristic = heur
        print('\n\n====================================================================================')
        print(f'Starting A* for {heur.identifier}')
        print('====================================================================================')
        solution = algo.run_algo()
        matrices = [matrix.state for matrix in solution]
        print(f'\nSequence of states from start to goal')
        print('+----------------------------------------------------------+')
        print_matrices(*matrices)
# Out:
# ====================================================================================
# Starting A* for NumOfTilesWrong
# ====================================================================================
#
# Display relevant costs...
# +----------------------------------------------------------+
# state = [['2', '1', '6'], ['4', '*', '8'], ['7', '5', '3']]; f(n) = 7; g(n) = 0; h(n) = 7; Number of nodes generated: 0
# state = [['2', '*', '6'], ['4', '1', '8'], ['7', '5', '3']]; f(n) = 8; g(n) = 1; h(n) = 7; Number of nodes generated: 4
# state = [['*', '2', '6'], ['4', '1', '8'], ['7', '5', '3']]; f(n) = 8; g(n) = 2; h(n) = 6; Number of nodes generated: 6
# state = [['2', '1', '6'], ['4', '5', '8'], ['7', '*', '3']]; f(n) = 8; g(n) = 1; h(n) = 7; Number of nodes generated: 7
# state = [['2', '1', '6'], ['*', '4', '8'], ['7', '5', '3']]; f(n) = 8; g(n) = 1; h(n) = 7; Number of nodes generated: 9
# state = [['2', '1', '6'], ['4', '8', '*'], ['7', '5', '3']]; f(n) = 8; g(n) = 1; h(n) = 7; Number of nodes generated: 11
# state = [['4', '2', '6'], ['*', '1', '8'], ['7', '5', '3']]; f(n) = 9; g(n) = 3; h(n) = 6; Number of nodes generated: 13
# state = [['2', '6', '*'], ['4', '1', '8'], ['7', '5', '3']]; f(n) = 9; g(n) = 2; h(n) = 7; Number of nodes generated: 15
# state = [['2', '1', '6'], ['4', '5', '8'], ['7', '3', '*']]; f(n) = 9; g(n) = 2; h(n) = 7; Number of nodes generated: 16
# state = [['*', '1', '6'], ['2', '4', '8'], ['7', '5', '3']]; f(n) = 9; g(n) = 2; h(n) = 7; Number of nodes generated: 17
# state = [['1', '*', '6'], ['2', '4', '8'], ['7', '5', '3']]; f(n) = 9; g(n) = 3; h(n) = 6; Number of nodes generated: 18
# state = [['2', '1', '*'], ['4', '8', '6'], ['7', '5', '3']]; f(n) = 9; g(n) = 2; h(n) = 7; Number of nodes generated: 20
# state = [['2', '1', '6'], ['4', '8', '3'], ['7', '5', '*']]; f(n) = 9; g(n) = 2; h(n) = 7; Number of nodes generated: 21
# state = [['2', '1', '6'], ['4', '8', '3'], ['7', '*', '5']]; f(n) = 9; g(n) = 3; h(n) = 6; Number of nodes generated: 22
# state = [['4', '2', '6'], ['1', '*', '8'], ['7', '5', '3']]; f(n) = 10; g(n) = 4; h(n) = 6; Number of nodes generated: 24
# state = [['1', '4', '6'], ['2', '*', '8'], ['7', '5', '3']]; f(n) = 10; g(n) = 4; h(n) = 6; Number of nodes generated: 27
# state = [['1', '6', '*'], ['2', '4', '8'], ['7', '5', '3']]; f(n) = 10; g(n) = 4; h(n) = 6; Number of nodes generated: 30
# state = [['2', '1', '6'], ['4', '*', '3'], ['7', '8', '5']]; f(n) = 10; g(n) = 4; h(n) = 6; Number of nodes generated: 31
# state = [['2', '6', '8'], ['4', '1', '*'], ['7', '5', '3']]; f(n) = 10; g(n) = 3; h(n) = 7; Number of nodes generated: 34
# state = [['2', '1', '6'], ['4', '5', '*'], ['7', '3', '8']]; f(n) = 10; g(n) = 3; h(n) = 7; Number of nodes generated: 36
# state = [['2', '*', '1'], ['4', '8', '6'], ['7', '5', '3']]; f(n) = 10; g(n) = 3; h(n) = 7; Number of nodes generated: 38
# state = [['*', '2', '1'], ['4', '8', '6'], ['7', '5', '3']]; f(n) = 10; g(n) = 4; h(n) = 6; Number of nodes generated: 40
# state = [['2', '1', '6'], ['4', '5', '8'], ['*', '7', '3']]; f(n) = 10; g(n) = 2; h(n) = 8; Number of nodes generated: 41
# state = [['2', '1', '6'], ['7', '4', '8'], ['*', '5', '3']]; f(n) = 10; g(n) = 2; h(n) = 8; Number of nodes generated: 42
# state = [['4', '2', '6'], ['1', '5', '8'], ['7', '*', '3']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 43
# state = [['4', '2', '6'], ['1', '8', '*'], ['7', '5', '3']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 45
# state = [['1', '4', '6'], ['2', '5', '8'], ['7', '*', '3']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 47
# state = [['1', '4', '6'], ['*', '2', '8'], ['7', '5', '3']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 49
# state = [['1', '4', '6'], ['2', '8', '*'], ['7', '5', '3']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 51
# state = [['1', '6', '8'], ['2', '4', '*'], ['7', '5', '3']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 53
# state = [['1', '6', '8'], ['2', '*', '4'], ['7', '5', '3']]; f(n) = 11; g(n) = 6; h(n) = 5; Number of nodes generated: 55
# state = [['2', '*', '6'], ['4', '1', '3'], ['7', '8', '5']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 58
# state = [['*', '2', '6'], ['4', '1', '3'], ['7', '8', '5']]; f(n) = 11; g(n) = 6; h(n) = 5; Number of nodes generated: 60
# state = [['2', '1', '6'], ['*', '4', '3'], ['7', '8', '5']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 61
# state = [['2', '1', '6'], ['4', '3', '*'], ['7', '8', '5']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 63
# state = [['4', '2', '1'], ['*', '8', '6'], ['7', '5', '3']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 65
# state = [['4', '2', '1'], ['8', '*', '6'], ['7', '5', '3']]; f(n) = 11; g(n) = 6; h(n) = 5; Number of nodes generated: 67
# state = [['4', '2', '6'], ['7', '1', '8'], ['*', '5', '3']]; f(n) = 11; g(n) = 4; h(n) = 7; Number of nodes generated: 70
# state = [['2', '1', '6'], ['4', '8', '3'], ['*', '7', '5']]; f(n) = 11; g(n) = 4; h(n) = 7; Number of nodes generated: 71
# state = [['2', '6', '8'], ['4', '1', '3'], ['7', '5', '*']]; f(n) = 11; g(n) = 4; h(n) = 7; Number of nodes generated: 72
# state = [['2', '6', '8'], ['4', '1', '3'], ['7', '*', '5']]; f(n) = 11; g(n) = 5; h(n) = 6; Number of nodes generated: 73
# state = [['2', '6', '8'], ['4', '*', '1'], ['7', '5', '3']]; f(n) = 11; g(n) = 4; h(n) = 7; Number of nodes generated: 75
# state = [['2', '1', '*'], ['4', '5', '6'], ['7', '3', '8']]; f(n) = 11; g(n) = 4; h(n) = 7; Number of nodes generated: 78
# state = [['2', '1', '6'], ['4', '*', '5'], ['7', '3', '8']]; f(n) = 11; g(n) = 4; h(n) = 7; Number of nodes generated: 79
# state = [['2', '8', '1'], ['4', '*', '6'], ['7', '5', '3']]; f(n) = 11; g(n) = 4; h(n) = 7; Number of nodes generated: 82
# state = [['2', '1', '6'], ['*', '5', '8'], ['4', '7', '3']]; f(n) = 11; g(n) = 3; h(n) = 8; Number of nodes generated: 85
# state = [['2', '1', '6'], ['7', '4', '8'], ['5', '*', '3']]; f(n) = 11; g(n) = 3; h(n) = 8; Number of nodes generated: 87
# state = [['1', '*', '8'], ['2', '6', '4'], ['7', '5', '3']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 89
# state = [['1', '6', '8'], ['2', '5', '4'], ['7', '*', '3']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 91
# state = [['1', '6', '8'], ['*', '2', '4'], ['7', '5', '3']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 93
# state = [['4', '2', '6'], ['*', '1', '3'], ['7', '8', '5']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 95
# state = [['4', '2', '1'], ['8', '5', '6'], ['7', '*', '3']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 97
# state = [['4', '2', '1'], ['8', '6', '*'], ['7', '5', '3']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 99
# state = [['4', '2', '6'], ['1', '5', '8'], ['7', '3', '*']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 101
# state = [['4', '2', '*'], ['1', '8', '6'], ['7', '5', '3']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 102
# state = [['4', '2', '6'], ['1', '8', '3'], ['7', '5', '*']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 103
# state = [['4', '2', '6'], ['1', '8', '3'], ['7', '*', '5']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 104
# state = [['1', '4', '6'], ['2', '5', '8'], ['7', '3', '*']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 106
# state = [['1', '4', '*'], ['2', '8', '6'], ['7', '5', '3']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 107
# state = [['1', '4', '6'], ['2', '8', '3'], ['7', '5', '*']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 108
# state = [['1', '4', '6'], ['2', '8', '3'], ['7', '*', '5']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 109
# state = [['1', '6', '8'], ['2', '4', '3'], ['7', '5', '*']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 111
# state = [['1', '6', '8'], ['2', '4', '3'], ['7', '*', '5']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 112
# state = [['2', '6', '*'], ['4', '1', '3'], ['7', '8', '5']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 114
# state = [['2', '6', '3'], ['4', '1', '*'], ['7', '8', '5']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 115
# state = [['*', '1', '6'], ['2', '4', '3'], ['7', '8', '5']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 117
# state = [['1', '*', '6'], ['2', '4', '3'], ['7', '8', '5']]; f(n) = 12; g(n) = 7; h(n) = 5; Number of nodes generated: 118
# state = [['2', '1', '*'], ['4', '3', '6'], ['7', '8', '5']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 120
# state = [['2', '6', '8'], ['4', '*', '3'], ['7', '1', '5']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 121
# state = [['4', '*', '6'], ['1', '2', '8'], ['7', '5', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 124
# state = [['4', '2', '6'], ['7', '1', '8'], ['5', '*', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 126
# state = [['2', '1', '6'], ['*', '8', '3'], ['4', '7', '5']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 128
# state = [['2', '1', '6'], ['8', '*', '3'], ['4', '7', '5']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 130
# state = [['2', '*', '8'], ['4', '6', '1'], ['7', '5', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 133
# state = [['*', '2', '8'], ['4', '6', '1'], ['7', '5', '3']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 135
# state = [['2', '6', '8'], ['4', '5', '1'], ['7', '*', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 136
# state = [['2', '6', '8'], ['*', '4', '1'], ['7', '5', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 138
# state = [['2', '*', '1'], ['4', '5', '6'], ['7', '3', '8']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 140
# state = [['*', '2', '1'], ['4', '5', '6'], ['7', '3', '8']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 142
# state = [['2', '*', '6'], ['4', '1', '5'], ['7', '3', '8']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 143
# state = [['*', '2', '6'], ['4', '1', '5'], ['7', '3', '8']]; f(n) = 12; g(n) = 6; h(n) = 6; Number of nodes generated: 145
# state = [['2', '1', '6'], ['4', '3', '5'], ['7', '*', '8']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 146
# state = [['2', '1', '6'], ['*', '4', '5'], ['7', '3', '8']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 148
# state = [['2', '8', '1'], ['4', '5', '6'], ['7', '*', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 150
# state = [['2', '8', '1'], ['*', '4', '6'], ['7', '5', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 152
# state = [['2', '8', '1'], ['4', '6', '*'], ['7', '5', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 154
# state = [['*', '1', '6'], ['2', '5', '8'], ['4', '7', '3']]; f(n) = 12; g(n) = 4; h(n) = 8; Number of nodes generated: 156
# state = [['1', '*', '6'], ['2', '5', '8'], ['4', '7', '3']]; f(n) = 12; g(n) = 5; h(n) = 7; Number of nodes generated: 157
# state = [['2', '1', '6'], ['5', '*', '8'], ['4', '7', '3']]; f(n) = 12; g(n) = 4; h(n) = 8; Number of nodes generated: 159
# state = [['2', '1', '6'], ['7', '*', '8'], ['5', '4', '3']]; f(n) = 12; g(n) = 4; h(n) = 8; Number of nodes generated: 162
# state = [['2', '1', '6'], ['7', '4', '8'], ['5', '3', '*']]; f(n) = 12; g(n) = 4; h(n) = 8; Number of nodes generated: 165
# state = [['1', '8', '*'], ['2', '6', '4'], ['7', '5', '3']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 166
# state = [['1', '6', '8'], ['2', '5', '4'], ['7', '3', '*']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 167
# state = [['4', '2', '6'], ['1', '*', '3'], ['7', '8', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 168
# state = [['4', '2', '1'], ['8', '5', '6'], ['7', '3', '*']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 171
# state = [['4', '2', '*'], ['8', '6', '1'], ['7', '5', '3']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 172
# state = [['4', '2', '1'], ['8', '6', '3'], ['7', '5', '*']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 173
# state = [['4', '2', '1'], ['8', '6', '3'], ['7', '*', '5']]; f(n) = 13; g(n) = 9; h(n) = 4; Number of nodes generated: 174
# state = [['4', '2', '1'], ['8', '*', '3'], ['7', '6', '5']]; f(n) = 13; g(n) = 10; h(n) = 3; Number of nodes generated: 176
# state = [['1', '4', '6'], ['2', '*', '3'], ['7', '8', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 179
# state = [['1', '6', '8'], ['2', '*', '3'], ['7', '4', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 182
# state = [['2', '6', '3'], ['4', '*', '1'], ['7', '8', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 185
# state = [['1', '6', '*'], ['2', '4', '3'], ['7', '8', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 188
# state = [['1', '6', '3'], ['2', '4', '*'], ['7', '8', '5']]; f(n) = 13; g(n) = 9; h(n) = 4; Number of nodes generated: 189
# state = [['1', '6', '3'], ['2', '*', '4'], ['7', '8', '5']]; f(n) = 13; g(n) = 10; h(n) = 3; Number of nodes generated: 191
# state = [['4', '*', '1'], ['8', '2', '6'], ['7', '5', '3']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 194
# state = [['4', '2', '6'], ['1', '5', '*'], ['7', '3', '8']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 196
# state = [['1', '4', '6'], ['2', '5', '*'], ['7', '3', '8']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 198
# state = [['1', '*', '4'], ['2', '8', '6'], ['7', '5', '3']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 200
# state = [['2', '*', '1'], ['4', '3', '6'], ['7', '8', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 202
# state = [['*', '2', '1'], ['4', '3', '6'], ['7', '8', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 204
# state = [['2', '*', '8'], ['4', '6', '3'], ['7', '1', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 205
# state = [['*', '2', '8'], ['4', '6', '3'], ['7', '1', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 207
# state = [['2', '6', '8'], ['*', '4', '3'], ['7', '1', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 208
# state = [['2', '6', '8'], ['4', '3', '*'], ['7', '1', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 210
# state = [['2', '*', '6'], ['8', '1', '3'], ['4', '7', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 212
# state = [['*', '2', '6'], ['8', '1', '3'], ['4', '7', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 214
# state = [['2', '1', '6'], ['8', '7', '3'], ['4', '*', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 215
# state = [['2', '1', '6'], ['8', '3', '*'], ['4', '7', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 217
# state = [['4', '2', '8'], ['*', '6', '1'], ['7', '5', '3']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 219
# state = [['4', '2', '1'], ['*', '5', '6'], ['7', '3', '8']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 221
# state = [['4', '2', '6'], ['*', '1', '5'], ['7', '3', '8']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 223
# state = [['4', '2', '6'], ['1', '5', '8'], ['*', '7', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 225
# state = [['1', '4', '6'], ['2', '5', '8'], ['*', '7', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 226
# state = [['*', '4', '6'], ['1', '2', '8'], ['7', '5', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 227
# state = [['1', '4', '6'], ['7', '2', '8'], ['*', '5', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 228
# state = [['2', '1', '6'], ['7', '4', '3'], ['*', '8', '5']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 229
# state = [['2', '1', '6'], ['4', '3', '5'], ['7', '8', '*']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 230
# state = [['4', '2', '1'], ['7', '8', '6'], ['*', '5', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 231
# state = [['2', '6', '8'], ['4', '1', '3'], ['*', '7', '5']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 232
# state = [['4', '6', '*'], ['1', '2', '8'], ['7', '5', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 233
# state = [['4', '2', '6'], ['7', '*', '8'], ['5', '1', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 234
# state = [['4', '2', '6'], ['7', '1', '8'], ['5', '3', '*']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 237
# state = [['*', '1', '6'], ['2', '8', '3'], ['4', '7', '5']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 238
# state = [['1', '*', '6'], ['2', '8', '3'], ['4', '7', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 239
# state = [['2', '8', '*'], ['4', '6', '1'], ['7', '5', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 241
# state = [['2', '6', '8'], ['4', '5', '1'], ['7', '3', '*']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 242
# state = [['*', '6', '8'], ['2', '4', '1'], ['7', '5', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 243
# state = [['2', '5', '1'], ['4', '*', '6'], ['7', '3', '8']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 244
# state = [['2', '6', '*'], ['4', '1', '5'], ['7', '3', '8']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 247
# state = [['*', '1', '6'], ['2', '4', '5'], ['7', '3', '8']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 248
# state = [['1', '*', '6'], ['2', '4', '5'], ['7', '3', '8']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 249
# state = [['2', '8', '1'], ['4', '5', '6'], ['7', '3', '*']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 251
# state = [['*', '8', '1'], ['2', '4', '6'], ['7', '5', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 252
# state = [['2', '8', '1'], ['4', '6', '3'], ['7', '5', '*']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 253
# state = [['2', '8', '1'], ['4', '6', '3'], ['7', '*', '5']]; f(n) = 13; g(n) = 7; h(n) = 6; Number of nodes generated: 254
# state = [['2', '8', '1'], ['4', '*', '3'], ['7', '6', '5']]; f(n) = 13; g(n) = 8; h(n) = 5; Number of nodes generated: 256
# state = [['1', '5', '6'], ['2', '*', '8'], ['4', '7', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 259
# state = [['1', '6', '*'], ['2', '5', '8'], ['4', '7', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 262
# state = [['2', '*', '6'], ['5', '1', '8'], ['4', '7', '3']]; f(n) = 13; g(n) = 5; h(n) = 8; Number of nodes generated: 263
# state = [['*', '2', '6'], ['5', '1', '8'], ['4', '7', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 265
# state = [['2', '1', '6'], ['5', '7', '8'], ['4', '*', '3']]; f(n) = 13; g(n) = 5; h(n) = 8; Number of nodes generated: 266
# state = [['2', '1', '6'], ['5', '8', '*'], ['4', '7', '3']]; f(n) = 13; g(n) = 5; h(n) = 8; Number of nodes generated: 268
# state = [['2', '*', '6'], ['7', '1', '8'], ['5', '4', '3']]; f(n) = 13; g(n) = 5; h(n) = 8; Number of nodes generated: 270
# state = [['*', '2', '6'], ['7', '1', '8'], ['5', '4', '3']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 272
# state = [['2', '1', '6'], ['*', '7', '8'], ['5', '4', '3']]; f(n) = 13; g(n) = 5; h(n) = 8; Number of nodes generated: 273
# state = [['2', '1', '6'], ['7', '8', '*'], ['5', '4', '3']]; f(n) = 13; g(n) = 5; h(n) = 8; Number of nodes generated: 275
# state = [['2', '1', '6'], ['7', '4', '*'], ['5', '3', '8']]; f(n) = 13; g(n) = 5; h(n) = 8; Number of nodes generated: 277
# state = [['2', '1', '6'], ['7', '*', '4'], ['5', '3', '8']]; f(n) = 13; g(n) = 6; h(n) = 7; Number of nodes generated: 279
# state = [['4', '2', '1'], ['8', '3', '*'], ['7', '6', '5']]; f(n) = 14; g(n) = 11; h(n) = 3; Number of nodes generated: 282
# state = [['1', '*', '3'], ['2', '6', '4'], ['7', '8', '5']]; f(n) = 14; g(n) = 11; h(n) = 3; Number of nodes generated: 284
# state = [['1', '6', '3'], ['2', '8', '4'], ['7', '*', '5']]; f(n) = 14; g(n) = 11; h(n) = 3; Number of nodes generated: 286
# state = [['1', '6', '3'], ['*', '2', '4'], ['7', '8', '5']]; f(n) = 14; g(n) = 11; h(n) = 3; Number of nodes generated: 288
# state = [['4', '2', '6'], ['1', '3', '*'], ['7', '8', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 290
# state = [['4', '2', '1'], ['8', '5', '*'], ['7', '3', '6']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 292
# state = [['1', '4', '6'], ['*', '2', '3'], ['7', '8', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 294
# state = [['1', '4', '6'], ['2', '3', '*'], ['7', '8', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 296
# state = [['1', '*', '8'], ['2', '6', '3'], ['7', '4', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 298
# state = [['1', '6', '8'], ['*', '2', '3'], ['7', '4', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 300
# state = [['1', '6', '8'], ['2', '3', '*'], ['7', '4', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 302
# state = [['2', '*', '3'], ['4', '6', '1'], ['7', '8', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 304
# state = [['*', '2', '3'], ['4', '6', '1'], ['7', '8', '5']]; f(n) = 14; g(n) = 10; h(n) = 4; Number of nodes generated: 306
# state = [['2', '6', '3'], ['4', '8', '1'], ['7', '*', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 307
# state = [['2', '6', '3'], ['*', '4', '1'], ['7', '8', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 309
# state = [['4', '2', '1'], ['*', '3', '6'], ['7', '8', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 311
# state = [['4', '2', '8'], ['*', '6', '3'], ['7', '1', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 313
# state = [['2', '*', '1'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 315
# state = [['*', '2', '1'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 14; g(n) = 10; h(n) = 4; Number of nodes generated: 317
# state = [['2', '8', '1'], ['*', '4', '3'], ['7', '6', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 318
# state = [['2', '8', '1'], ['4', '3', '*'], ['7', '6', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 320
# state = [['*', '1', '8'], ['2', '6', '4'], ['7', '5', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 322
# state = [['1', '6', '8'], ['2', '5', '4'], ['*', '7', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 323
# state = [['*', '6', '8'], ['1', '2', '4'], ['7', '5', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 324
# state = [['1', '6', '8'], ['7', '2', '4'], ['*', '5', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 325
# state = [['4', '2', '6'], ['7', '1', '3'], ['*', '8', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 326
# state = [['4', '2', '1'], ['8', '5', '6'], ['*', '7', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 327
# state = [['4', '2', '6'], ['1', '8', '3'], ['*', '7', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 328
# state = [['1', '4', '6'], ['2', '8', '3'], ['*', '7', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 329
# state = [['1', '6', '8'], ['2', '4', '3'], ['*', '7', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 330
# state = [['2', '6', '3'], ['4', '1', '5'], ['7', '8', '*']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 331
# state = [['*', '4', '1'], ['8', '2', '6'], ['7', '5', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 332
# state = [['4', '1', '*'], ['8', '2', '6'], ['7', '5', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 333
# state = [['4', '2', '*'], ['1', '5', '6'], ['7', '3', '8']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 334
# state = [['4', '2', '6'], ['1', '*', '5'], ['7', '3', '8']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 335
# state = [['1', '4', '*'], ['2', '5', '6'], ['7', '3', '8']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 338
# state = [['1', '4', '6'], ['2', '*', '5'], ['7', '3', '8']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 339
# state = [['1', '8', '4'], ['2', '*', '6'], ['7', '5', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 342
# state = [['2', '3', '1'], ['4', '*', '6'], ['7', '8', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 345
# state = [['2', '8', '*'], ['4', '6', '3'], ['7', '1', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 348
# state = [['2', '8', '3'], ['4', '6', '*'], ['7', '1', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 349
# state = [['*', '6', '8'], ['2', '4', '3'], ['7', '1', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 351
# state = [['2', '6', '*'], ['4', '3', '8'], ['7', '1', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 352
# state = [['2', '6', '*'], ['8', '1', '3'], ['4', '7', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 353
# state = [['2', '6', '3'], ['8', '1', '*'], ['4', '7', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 354
# state = [['2', '1', '6'], ['8', '7', '3'], ['*', '4', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 356
# state = [['2', '1', '*'], ['8', '3', '6'], ['4', '7', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 357
# state = [['4', '2', '8'], ['6', '*', '1'], ['7', '5', '3']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 358
# state = [['4', '2', '1'], ['5', '*', '6'], ['7', '3', '8']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 361
# state = [['1', '8', '6'], ['2', '*', '3'], ['4', '7', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 364
# state = [['1', '6', '*'], ['2', '8', '3'], ['4', '7', '5']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 367
# state = [['1', '6', '3'], ['2', '8', '*'], ['4', '7', '5']]; f(n) = 14; g(n) = 9; h(n) = 5; Number of nodes generated: 368
# state = [['1', '6', '*'], ['2', '4', '5'], ['7', '3', '8']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 370
# state = [['4', '*', '2'], ['1', '8', '6'], ['7', '5', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 371
# state = [['4', '2', '6'], ['*', '5', '8'], ['1', '7', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 373
# state = [['1', '4', '6'], ['*', '5', '8'], ['2', '7', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 375
# state = [['1', '4', '6'], ['7', '2', '8'], ['5', '*', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 377
# state = [['2', '1', '6'], ['7', '4', '3'], ['8', '*', '5']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 379
# state = [['4', '2', '1'], ['7', '8', '6'], ['5', '*', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 381
# state = [['2', '6', '8'], ['*', '1', '3'], ['4', '7', '5']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 383
# state = [['4', '6', '8'], ['1', '2', '*'], ['7', '5', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 385
# state = [['4', '2', '6'], ['*', '7', '8'], ['5', '1', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 387
# state = [['4', '2', '6'], ['7', '8', '*'], ['5', '1', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 389
# state = [['4', '2', '6'], ['7', '1', '*'], ['5', '3', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 391
# state = [['2', '6', '8'], ['4', '5', '*'], ['7', '3', '1']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 393
# state = [['6', '*', '8'], ['2', '4', '1'], ['7', '5', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 395
# state = [['2', '5', '1'], ['4', '3', '6'], ['7', '*', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 397
# state = [['2', '5', '1'], ['*', '4', '6'], ['7', '3', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 399
# state = [['2', '5', '1'], ['4', '6', '*'], ['7', '3', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 401
# state = [['2', '6', '5'], ['4', '1', '*'], ['7', '3', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 403
# state = [['2', '8', '1'], ['4', '5', '*'], ['7', '3', '6']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 405
# state = [['8', '*', '1'], ['2', '4', '6'], ['7', '5', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 407
# state = [['1', '5', '6'], ['2', '7', '8'], ['4', '*', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 409
# state = [['1', '5', '6'], ['*', '2', '8'], ['4', '7', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 411
# state = [['1', '5', '6'], ['2', '8', '*'], ['4', '7', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 413
# state = [['1', '6', '8'], ['2', '5', '*'], ['4', '7', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 415
# state = [['5', '2', '6'], ['*', '1', '8'], ['4', '7', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 417
# state = [['7', '2', '6'], ['*', '1', '8'], ['5', '4', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 419
# state = [['2', '*', '6'], ['7', '1', '4'], ['5', '3', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 421
# state = [['*', '2', '6'], ['7', '1', '4'], ['5', '3', '8']]; f(n) = 14; g(n) = 8; h(n) = 6; Number of nodes generated: 423
# state = [['2', '1', '6'], ['7', '3', '4'], ['5', '*', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 424
# state = [['2', '1', '6'], ['*', '7', '4'], ['5', '3', '8']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 426
# state = [['2', '6', '8'], ['4', '5', '1'], ['*', '7', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 428
# state = [['2', '6', '8'], ['7', '4', '1'], ['*', '5', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 429
# state = [['2', '1', '6'], ['4', '3', '5'], ['*', '7', '8']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 430
# state = [['2', '1', '6'], ['7', '4', '5'], ['*', '3', '8']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 431
# state = [['2', '8', '1'], ['4', '5', '6'], ['*', '7', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 432
# state = [['2', '8', '1'], ['7', '4', '6'], ['*', '5', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 433
# state = [['2', '6', '*'], ['5', '1', '8'], ['4', '7', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 434
# state = [['2', '1', '6'], ['5', '7', '8'], ['*', '4', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 435
# state = [['2', '1', '6'], ['5', '7', '8'], ['4', '3', '*']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 436
# state = [['2', '1', '*'], ['5', '8', '6'], ['4', '7', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 437
# state = [['2', '1', '6'], ['5', '8', '3'], ['4', '7', '*']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 438
# state = [['2', '6', '*'], ['7', '1', '8'], ['5', '4', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 439
# state = [['*', '1', '6'], ['2', '7', '8'], ['5', '4', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 440
# state = [['1', '*', '6'], ['2', '7', '8'], ['5', '4', '3']]; f(n) = 14; g(n) = 7; h(n) = 7; Number of nodes generated: 441
# state = [['2', '1', '*'], ['7', '8', '6'], ['5', '4', '3']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 443
# state = [['2', '1', '6'], ['7', '8', '3'], ['5', '4', '*']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 444
# state = [['2', '1', '*'], ['7', '4', '6'], ['5', '3', '8']]; f(n) = 14; g(n) = 6; h(n) = 8; Number of nodes generated: 445
# state = [['4', '2', '*'], ['8', '3', '1'], ['7', '6', '5']]; f(n) = 15; g(n) = 12; h(n) = 3; Number of nodes generated: 446
# state = [['4', '*', '1'], ['8', '2', '3'], ['7', '6', '5']]; f(n) = 15; g(n) = 11; h(n) = 4; Number of nodes generated: 447
# state = [['4', '2', '1'], ['*', '8', '3'], ['7', '6', '5']]; f(n) = 15; g(n) = 11; h(n) = 4; Number of nodes generated: 449
# state = [['4', '2', '3'], ['*', '6', '1'], ['7', '8', '5']]; f(n) = 15; g(n) = 11; h(n) = 4; Number of nodes generated: 451
# state = [['4', '2', '1'], ['8', '6', '3'], ['*', '7', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 453
# state = [['1', '6', '3'], ['2', '4', '5'], ['7', '8', '*']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 454
# state = [['4', '2', '*'], ['1', '3', '6'], ['7', '8', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 455
# state = [['4', '2', '*'], ['8', '5', '1'], ['7', '3', '6']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 456
# state = [['4', '2', '1'], ['8', '*', '5'], ['7', '3', '6']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 457
# state = [['1', '4', '*'], ['2', '3', '6'], ['7', '8', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 460
# state = [['1', '8', '*'], ['2', '6', '3'], ['7', '4', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 461
# state = [['1', '8', '3'], ['2', '6', '*'], ['7', '4', '5']]; f(n) = 15; g(n) = 11; h(n) = 4; Number of nodes generated: 462
# state = [['1', '6', '*'], ['2', '3', '8'], ['7', '4', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 464
# state = [['*', '6', '3'], ['2', '4', '1'], ['7', '8', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 465
# state = [['4', '2', '1'], ['3', '*', '6'], ['7', '8', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 466
# state = [['4', '2', '8'], ['6', '*', '3'], ['7', '1', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 469
# state = [['2', '1', '*'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 472
# state = [['2', '1', '3'], ['4', '8', '*'], ['7', '6', '5']]; f(n) = 15; g(n) = 11; h(n) = 4; Number of nodes generated: 473
# state = [['*', '8', '1'], ['2', '4', '3'], ['7', '6', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 475
# state = [['2', '8', '*'], ['4', '3', '1'], ['7', '6', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 476
# state = [['2', '8', '3'], ['4', '*', '6'], ['7', '1', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 477
# state = [['2', '6', '3'], ['8', '*', '1'], ['4', '7', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 480
# state = [['1', '6', '3'], ['2', '*', '8'], ['4', '7', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 483
# state = [['1', '8', '4'], ['2', '6', '*'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 486
# state = [['1', '6', '8'], ['2', '5', '*'], ['7', '3', '4']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 488
# state = [['4', '*', '6'], ['1', '2', '3'], ['7', '8', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 490
# state = [['4', '*', '2'], ['8', '6', '1'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 492
# state = [['8', '2', '6'], ['*', '1', '3'], ['4', '7', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 494
# state = [['2', '1', '8'], ['*', '6', '4'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 496
# state = [['1', '6', '8'], ['*', '5', '4'], ['2', '7', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 498
# state = [['6', '*', '8'], ['1', '2', '4'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 500
# state = [['6', '2', '8'], ['1', '*', '4'], ['7', '5', '3']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 502
# state = [['1', '6', '8'], ['7', '2', '4'], ['5', '*', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 505
# state = [['4', '2', '6'], ['7', '1', '3'], ['8', '*', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 507
# state = [['4', '2', '6'], ['*', '8', '3'], ['1', '7', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 509
# state = [['4', '2', '6'], ['8', '*', '3'], ['1', '7', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 511
# state = [['1', '4', '6'], ['*', '8', '3'], ['2', '7', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 514
# state = [['1', '4', '6'], ['8', '*', '3'], ['2', '7', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 516
# state = [['1', '6', '8'], ['*', '4', '3'], ['2', '7', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 519
# state = [['2', '6', '3'], ['4', '1', '5'], ['7', '*', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 521
# state = [['4', '1', '6'], ['8', '2', '*'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 523
# state = [['4', '2', '6'], ['1', '3', '5'], ['7', '*', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 525
# state = [['1', '*', '4'], ['2', '5', '6'], ['7', '3', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 527
# state = [['1', '4', '6'], ['2', '3', '5'], ['7', '*', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 529
# state = [['1', '4', '6'], ['*', '2', '5'], ['7', '3', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 531
# state = [['1', '8', '4'], ['2', '5', '6'], ['7', '*', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 533
# state = [['1', '8', '4'], ['*', '2', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 535
# state = [['2', '3', '1'], ['4', '8', '6'], ['7', '*', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 537
# state = [['2', '3', '1'], ['*', '4', '6'], ['7', '8', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 539
# state = [['2', '3', '1'], ['4', '6', '*'], ['7', '8', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 541
# state = [['6', '*', '8'], ['2', '4', '3'], ['7', '1', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 543
# state = [['2', '*', '6'], ['4', '3', '8'], ['7', '1', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 545
# state = [['*', '2', '6'], ['4', '3', '8'], ['7', '1', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 547
# state = [['2', '*', '1'], ['8', '3', '6'], ['4', '7', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 548
# state = [['*', '2', '1'], ['8', '3', '6'], ['4', '7', '5']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 550
# state = [['4', '2', '8'], ['6', '5', '1'], ['7', '*', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 551
# state = [['4', '2', '8'], ['6', '1', '*'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 553
# state = [['4', '2', '1'], ['5', '3', '6'], ['7', '*', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 555
# state = [['4', '2', '1'], ['5', '6', '*'], ['7', '3', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 557
# state = [['1', '8', '6'], ['2', '7', '3'], ['4', '*', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 559
# state = [['1', '8', '6'], ['*', '2', '3'], ['4', '7', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 561
# state = [['1', '8', '6'], ['2', '3', '*'], ['4', '7', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 563
# state = [['1', '6', '5'], ['2', '4', '*'], ['7', '3', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 565
# state = [['1', '6', '5'], ['2', '*', '4'], ['7', '3', '8']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 567
# state = [['7', '2', '6'], ['*', '1', '4'], ['5', '3', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 570
# state = [['*', '1', '4'], ['2', '8', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 572
# state = [['2', '6', '8'], ['7', '4', '3'], ['*', '1', '5']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 573
# state = [['2', '6', '8'], ['4', '3', '5'], ['7', '1', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 574
# state = [['2', '1', '6'], ['8', '7', '3'], ['4', '5', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 575
# state = [['2', '1', '6'], ['8', '3', '5'], ['4', '7', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 576
# state = [['4', '2', '8'], ['7', '6', '1'], ['*', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 577
# state = [['4', '2', '1'], ['7', '5', '6'], ['*', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 578
# state = [['4', '2', '6'], ['7', '1', '5'], ['*', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 579
# state = [['2', '8', '1'], ['4', '6', '3'], ['*', '7', '5']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 580
# state = [['4', '8', '2'], ['1', '*', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 581
# state = [['*', '4', '2'], ['1', '8', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 584
# state = [['1', '4', '2'], ['*', '8', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 585
# state = [['1', '4', '2'], ['8', '*', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 10; h(n) = 5; Number of nodes generated: 587
# state = [['*', '2', '6'], ['4', '5', '8'], ['1', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 590
# state = [['4', '2', '6'], ['5', '*', '8'], ['1', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 591
# state = [['1', '4', '6'], ['5', '*', '8'], ['2', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 594
# state = [['1', '4', '6'], ['7', '*', '8'], ['5', '2', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 597
# state = [['1', '4', '6'], ['7', '2', '8'], ['5', '3', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 600
# state = [['2', '1', '6'], ['7', '*', '3'], ['8', '4', '5']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 601
# state = [['4', '2', '1'], ['7', '*', '6'], ['5', '8', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 604
# state = [['4', '2', '1'], ['7', '8', '6'], ['5', '3', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 607
# state = [['*', '6', '8'], ['2', '1', '3'], ['4', '7', '5']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 608
# state = [['2', '6', '8'], ['1', '*', '3'], ['4', '7', '5']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 609
# state = [['4', '6', '8'], ['1', '2', '3'], ['7', '5', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 612
# state = [['4', '6', '8'], ['1', '2', '3'], ['7', '*', '5']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 613
# state = [['4', '6', '8'], ['1', '*', '2'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 615
# state = [['*', '2', '6'], ['4', '7', '8'], ['5', '1', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 618
# state = [['4', '2', '6'], ['5', '7', '8'], ['*', '1', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 619
# state = [['4', '2', '*'], ['7', '8', '6'], ['5', '1', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 620
# state = [['4', '2', '6'], ['7', '8', '3'], ['5', '1', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 621
# state = [['4', '2', '*'], ['7', '1', '6'], ['5', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 622
# state = [['4', '2', '6'], ['7', '*', '1'], ['5', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 623
# state = [['2', '6', '*'], ['4', '5', '8'], ['7', '3', '1']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 626
# state = [['2', '6', '8'], ['4', '*', '5'], ['7', '3', '1']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 627
# state = [['6', '4', '8'], ['2', '*', '1'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 630
# state = [['6', '8', '*'], ['2', '4', '1'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 633
# state = [['2', '5', '1'], ['4', '3', '6'], ['7', '8', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 634
# state = [['*', '5', '1'], ['2', '4', '6'], ['7', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 635
# state = [['2', '5', '*'], ['4', '6', '1'], ['7', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 636
# state = [['2', '5', '1'], ['4', '6', '8'], ['7', '3', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 637
# state = [['2', '6', '5'], ['4', '1', '8'], ['7', '3', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 638
# state = [['2', '6', '5'], ['4', '*', '1'], ['7', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 639
# state = [['2', '8', '*'], ['4', '5', '1'], ['7', '3', '6']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 642
# state = [['2', '8', '1'], ['4', '*', '5'], ['7', '3', '6']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 643
# state = [['8', '4', '1'], ['2', '*', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 646
# state = [['8', '1', '*'], ['2', '4', '6'], ['7', '5', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 649
# state = [['1', '5', '6'], ['2', '7', '8'], ['*', '4', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 650
# state = [['1', '5', '6'], ['2', '7', '8'], ['4', '3', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 651
# state = [['1', '5', '6'], ['4', '2', '8'], ['*', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 652
# state = [['1', '5', '6'], ['4', '2', '8'], ['7', '*', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 653
# state = [['1', '5', '*'], ['2', '8', '6'], ['4', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 655
# state = [['1', '5', '6'], ['2', '8', '3'], ['4', '7', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 656
# state = [['1', '6', '8'], ['2', '5', '3'], ['4', '7', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 657
# state = [['1', '6', '8'], ['2', '*', '5'], ['4', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 658
# state = [['5', '2', '6'], ['4', '1', '8'], ['*', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 661
# state = [['5', '2', '6'], ['4', '1', '8'], ['7', '*', '3']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 662
# state = [['5', '2', '6'], ['1', '*', '8'], ['4', '7', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 664
# state = [['7', '2', '6'], ['5', '1', '8'], ['*', '4', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 667
# state = [['7', '2', '6'], ['1', '*', '8'], ['5', '4', '3']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 668
# state = [['2', '6', '*'], ['7', '1', '4'], ['5', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 671
# state = [['2', '1', '6'], ['7', '3', '4'], ['*', '5', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 672
# state = [['2', '1', '6'], ['*', '3', '4'], ['7', '5', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 673
# state = [['2', '1', '6'], ['7', '3', '4'], ['5', '8', '*']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 675
# state = [['*', '1', '6'], ['2', '7', '4'], ['5', '3', '8']]; f(n) = 15; g(n) = 8; h(n) = 7; Number of nodes generated: 676
# state = [['1', '*', '6'], ['2', '7', '4'], ['5', '3', '8']]; f(n) = 15; g(n) = 9; h(n) = 6; Number of nodes generated: 677
# ...
# state = [['2', '*', '6'], ['4', '1', '3'], ['7', '8', '5']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 50
# state = [['*', '2', '6'], ['4', '1', '3'], ['7', '8', '5']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 52
# state = [['2', '6', '*'], ['4', '1', '3'], ['7', '8', '5']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 53
# state = [['2', '6', '3'], ['4', '1', '*'], ['7', '8', '5']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 54
# state = [['2', '1', '6'], ['4', '3', '*'], ['7', '8', '5']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 56
# state = [['2', '1', '*'], ['4', '3', '6'], ['7', '8', '5']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 58
# state = [['2', '1', '6'], ['*', '8', '3'], ['4', '7', '5']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 59
# state = [['2', '1', '6'], ['8', '*', '3'], ['4', '7', '5']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 61
# state = [['4', '2', '1'], ['*', '8', '6'], ['7', '5', '3']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 64
# state = [['4', '2', '1'], ['8', '*', '6'], ['7', '5', '3']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 66
# state = [['4', '2', '1'], ['8', '6', '*'], ['7', '5', '3']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 69
# state = [['4', '2', '1'], ['8', '6', '3'], ['7', '5', '*']]; f(n) = 16; g(n) = 8; h(n) = 8; Number of nodes generated: 71
# state = [['4', '2', '1'], ['8', '6', '3'], ['7', '*', '5']]; f(n) = 16; g(n) = 9; h(n) = 7; Number of nodes generated: 72
# state = [['4', '2', '1'], ['8', '*', '3'], ['7', '6', '5']]; f(n) = 16; g(n) = 10; h(n) = 6; Number of nodes generated: 74
# state = [['1', '6', '8'], ['2', '4', '*'], ['7', '5', '3']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 77
# state = [['1', '6', '8'], ['2', '4', '3'], ['7', '5', '*']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 79
# state = [['1', '6', '8'], ['2', '4', '3'], ['7', '*', '5']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 80
# state = [['1', '6', '8'], ['2', '*', '4'], ['7', '5', '3']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 82
# state = [['1', '*', '8'], ['2', '6', '4'], ['7', '5', '3']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 85
# state = [['1', '8', '*'], ['2', '6', '4'], ['7', '5', '3']]; f(n) = 16; g(n) = 8; h(n) = 8; Number of nodes generated: 87
# state = [['1', '6', '8'], ['*', '2', '4'], ['7', '5', '3']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 88
# state = [['2', '8', '1'], ['4', '*', '6'], ['7', '5', '3']]; f(n) = 16; g(n) = 4; h(n) = 12; Number of nodes generated: 90
# state = [['2', '8', '1'], ['*', '4', '6'], ['7', '5', '3']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 93
# state = [['2', '8', '1'], ['4', '6', '*'], ['7', '5', '3']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 95
# state = [['2', '8', '1'], ['4', '6', '3'], ['7', '5', '*']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 97
# state = [['2', '8', '1'], ['4', '6', '3'], ['7', '*', '5']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 98
# state = [['2', '8', '1'], ['4', '*', '3'], ['7', '6', '5']]; f(n) = 16; g(n) = 8; h(n) = 8; Number of nodes generated: 100
# state = [['2', '*', '1'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 16; g(n) = 9; h(n) = 7; Number of nodes generated: 103
# state = [['*', '2', '1'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 16; g(n) = 10; h(n) = 6; Number of nodes generated: 105
# state = [['2', '1', '*'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 16; g(n) = 10; h(n) = 6; Number of nodes generated: 106
# state = [['2', '1', '3'], ['4', '8', '*'], ['7', '6', '5']]; f(n) = 16; g(n) = 11; h(n) = 5; Number of nodes generated: 107
# state = [['2', '8', '1'], ['*', '4', '3'], ['7', '6', '5']]; f(n) = 16; g(n) = 9; h(n) = 7; Number of nodes generated: 109
# state = [['1', '4', '6'], ['2', '*', '8'], ['7', '5', '3']]; f(n) = 16; g(n) = 4; h(n) = 12; Number of nodes generated: 111
# state = [['1', '4', '6'], ['*', '2', '8'], ['7', '5', '3']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 114
# state = [['1', '4', '6'], ['2', '8', '*'], ['7', '5', '3']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 116
# state = [['1', '4', '*'], ['2', '8', '6'], ['7', '5', '3']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 118
# state = [['1', '*', '4'], ['2', '8', '6'], ['7', '5', '3']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 119
# state = [['1', '4', '6'], ['2', '8', '3'], ['7', '5', '*']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 121
# state = [['1', '4', '6'], ['2', '8', '3'], ['7', '*', '5']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 122
# state = [['2', '1', '6'], ['7', '4', '8'], ['5', '*', '3']]; f(n) = 16; g(n) = 3; h(n) = 13; Number of nodes generated: 124
# state = [['4', '2', '6'], ['*', '1', '8'], ['7', '5', '3']]; f(n) = 16; g(n) = 3; h(n) = 13; Number of nodes generated: 126
# state = [['4', '2', '6'], ['1', '*', '8'], ['7', '5', '3']]; f(n) = 16; g(n) = 4; h(n) = 12; Number of nodes generated: 128
# state = [['4', '2', '6'], ['1', '8', '*'], ['7', '5', '3']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 131
# state = [['4', '2', '*'], ['1', '8', '6'], ['7', '5', '3']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 133
# state = [['4', '2', '6'], ['1', '8', '3'], ['7', '5', '*']]; f(n) = 16; g(n) = 6; h(n) = 10; Number of nodes generated: 134
# state = [['4', '2', '6'], ['1', '8', '3'], ['7', '*', '5']]; f(n) = 16; g(n) = 7; h(n) = 9; Number of nodes generated: 135
# state = [['2', '6', '8'], ['4', '1', '*'], ['7', '5', '3']]; f(n) = 16; g(n) = 3; h(n) = 13; Number of nodes generated: 137
# state = [['2', '6', '8'], ['4', '1', '3'], ['7', '5', '*']]; f(n) = 16; g(n) = 4; h(n) = 12; Number of nodes generated: 139
# state = [['2', '6', '8'], ['4', '1', '3'], ['7', '*', '5']]; f(n) = 16; g(n) = 5; h(n) = 11; Number of nodes generated: 140
# state = [['2', '1', '6'], ['4', '5', '8'], ['*', '7', '3']]; f(n) = 16; g(n) = 2; h(n) = 14; Number of nodes generated: 142
# state = [['2', '1', '6'], ['4', '5', '8'], ['7', '3', '*']]; f(n) = 16; g(n) = 2; h(n) = 14; Number of nodes generated: 143
# state = [['*', '1', '3'], ['2', '6', '4'], ['7', '8', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 144
# state = [['2', '1', '3'], ['*', '6', '4'], ['7', '8', '5']]; f(n) = 18; g(n) = 13; h(n) = 5; Number of nodes generated: 145
# state = [['1', '3', '*'], ['2', '6', '4'], ['7', '8', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 147
# state = [['1', '6', '3'], ['2', '8', '4'], ['*', '7', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 148
# state = [['1', '6', '3'], ['2', '8', '4'], ['7', '5', '*']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 149
# state = [['*', '6', '3'], ['1', '2', '4'], ['7', '8', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 150
# state = [['1', '6', '3'], ['7', '2', '4'], ['*', '8', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 151
# state = [['1', '6', '3'], ['7', '2', '4'], ['8', '*', '5']]; f(n) = 18; g(n) = 13; h(n) = 5; Number of nodes generated: 152
# state = [['2', '1', '3'], ['4', '8', '5'], ['7', '6', '*']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 154
# state = [['2', '1', '3'], ['4', '*', '8'], ['7', '6', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 155
# state = [['2', '1', '3'], ['*', '4', '8'], ['7', '6', '5']]; f(n) = 18; g(n) = 13; h(n) = 5; Number of nodes generated: 158
# state = [['4', '*', '1'], ['8', '2', '3'], ['7', '6', '5']]; f(n) = 18; g(n) = 11; h(n) = 7; Number of nodes generated: 160
# state = [['*', '4', '1'], ['8', '2', '3'], ['7', '6', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 162
# state = [['4', '1', '*'], ['8', '2', '3'], ['7', '6', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 163
# state = [['4', '1', '3'], ['8', '2', '*'], ['7', '6', '5']]; f(n) = 18; g(n) = 13; h(n) = 5; Number of nodes generated: 164
# state = [['4', '2', '1'], ['*', '8', '3'], ['7', '6', '5']]; f(n) = 18; g(n) = 11; h(n) = 7; Number of nodes generated: 166
# state = [['4', '2', '1'], ['8', '3', '*'], ['7', '6', '5']]; f(n) = 18; g(n) = 11; h(n) = 7; Number of nodes generated: 168
# state = [['1', '6', '3'], ['2', '4', '5'], ['7', '8', '*']]; f(n) = 18; g(n) = 10; h(n) = 8; Number of nodes generated: 170
# state = [['4', '2', '1'], ['8', '6', '3'], ['*', '7', '5']]; f(n) = 18; g(n) = 10; h(n) = 8; Number of nodes generated: 171
# state = [['*', '8', '1'], ['2', '4', '3'], ['7', '6', '5']]; f(n) = 18; g(n) = 10; h(n) = 8; Number of nodes generated: 172
# state = [['8', '*', '1'], ['2', '4', '3'], ['7', '6', '5']]; f(n) = 18; g(n) = 11; h(n) = 7; Number of nodes generated: 173
# state = [['8', '1', '*'], ['2', '4', '3'], ['7', '6', '5']]; f(n) = 18; g(n) = 12; h(n) = 6; Number of nodes generated: 175
# state = [['8', '1', '3'], ['2', '4', '*'], ['7', '6', '5']]; f(n) = 18; g(n) = 13; h(n) = 5; Number of nodes generated: 176
# state = [['8', '1', '3'], ['2', '*', '4'], ['7', '6', '5']]; f(n) = 18; g(n) = 14; h(n) = 4; Number of nodes generated: 178
# state = [['8', '1', '3'], ['*', '2', '4'], ['7', '6', '5']]; f(n) = 18; g(n) = 15; h(n) = 3; Number of nodes generated: 181
# state = [['*', '1', '3'], ['8', '2', '4'], ['7', '6', '5']]; f(n) = 18; g(n) = 16; h(n) = 2; Number of nodes generated: 183
# state = [['1', '*', '3'], ['8', '2', '4'], ['7', '6', '5']]; f(n) = 18; g(n) = 17; h(n) = 1; Number of nodes generated: 184
# state = [['1', '2', '3'], ['8', '*', '4'], ['7', '6', '5']]; f(n) = 18; g(n) = 18; h(n) = 0; Number of nodes generated: 186
#
# Summary for A* using ManhattanDistance
# +----------------------------------------------------------+
# Nodes generated: 186; Unique nodes generated: 183; Nodes expanded: 107
# Open List: 76; Closed List: 108
#
# Sequence of states from start to goal
# +----------------------------------------------------------+
# Moves 0 to 9
# 2 1 6    2 1 6    2 1 *    2 * 1    2 8 1    2 8 1    2 8 1    2 8 1    2 8 1    2 8 1
# 4 * 8 -> 4 8 * -> 4 8 6 -> 4 8 6 -> 4 * 6 -> 4 6 * -> 4 6 3 -> 4 6 3 -> 4 * 3 -> * 4 3
# 7 5 3    7 5 3    7 5 3    7 5 3    7 5 3    7 5 3    7 5 *    7 * 5    7 6 5    7 6 5
# Moves 10 to 18
# * 8 1    8 * 1    8 1 *    8 1 3    8 1 3    8 1 3    * 1 3    1 * 3    1 2 3
# 2 4 3 -> 2 4 3 -> 2 4 3 -> 2 4 * -> 2 * 4 -> * 2 4 -> 8 2 4 -> 8 2 4 -> 8 * 4
# 7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5
#
#
# ====================================================================================
# Starting A* for NilssonSequenceScore
# ====================================================================================
#
# Display relevant costs...
# +----------------------------------------------------------+
# state = [['2', '1', '6'], ['4', '*', '8'], ['7', '5', '3']]; f(n) = 60; g(n) = 0; h(n) = 60; p(n) = 12; s(n) = 16; Number of nodes generated: 0
# state = [['2', '1', '6'], ['*', '4', '8'], ['7', '5', '3']]; f(n) = 57; g(n) = 1; h(n) = 56; p(n) = 11; s(n) = 15; Number of nodes generated: 4
# state = [['2', '1', '6'], ['4', '8', '*'], ['7', '5', '3']]; f(n) = 57; g(n) = 1; h(n) = 56; p(n) = 11; s(n) = 15; Number of nodes generated: 6
# state = [['2', '1', '*'], ['4', '8', '6'], ['7', '5', '3']]; f(n) = 57; g(n) = 2; h(n) = 55; p(n) = 10; s(n) = 15; Number of nodes generated: 8
# state = [['2', '1', '6'], ['4', '8', '3'], ['7', '5', '*']]; f(n) = 57; g(n) = 2; h(n) = 55; p(n) = 10; s(n) = 15; Number of nodes generated: 9
# state = [['2', '1', '6'], ['4', '8', '3'], ['7', '*', '5']]; f(n) = 57; g(n) = 3; h(n) = 54; p(n) = 9; s(n) = 15; Number of nodes generated: 10
# state = [['2', '1', '6'], ['4', '8', '3'], ['*', '7', '5']]; f(n) = 59; g(n) = 4; h(n) = 55; p(n) = 10; s(n) = 15; Number of nodes generated: 12
# state = [['2', '*', '1'], ['4', '8', '6'], ['7', '5', '3']]; f(n) = 59; g(n) = 3; h(n) = 56; p(n) = 11; s(n) = 15; Number of nodes generated: 13
# state = [['2', '8', '1'], ['4', '*', '6'], ['7', '5', '3']]; f(n) = 58; g(n) = 4; h(n) = 54; p(n) = 12; s(n) = 14; Number of nodes generated: 15
# state = [['2', '8', '1'], ['*', '4', '6'], ['7', '5', '3']]; f(n) = 55; g(n) = 5; h(n) = 50; p(n) = 11; s(n) = 13; Number of nodes generated: 18
# state = [['2', '8', '1'], ['4', '6', '*'], ['7', '5', '3']]; f(n) = 55; g(n) = 5; h(n) = 50; p(n) = 11; s(n) = 13; Number of nodes generated: 20
# state = [['2', '8', '1'], ['4', '6', '3'], ['7', '5', '*']]; f(n) = 55; g(n) = 6; h(n) = 49; p(n) = 10; s(n) = 13; Number of nodes generated: 22
# state = [['2', '8', '1'], ['4', '6', '3'], ['7', '*', '5']]; f(n) = 55; g(n) = 7; h(n) = 48; p(n) = 9; s(n) = 13; Number of nodes generated: 23
# state = [['2', '8', '1'], ['4', '*', '3'], ['7', '6', '5']]; f(n) = 46; g(n) = 8; h(n) = 38; p(n) = 8; s(n) = 10; Number of nodes generated: 25
# state = [['2', '8', '1'], ['*', '4', '3'], ['7', '6', '5']]; f(n) = 43; g(n) = 9; h(n) = 34; p(n) = 7; s(n) = 9; Number of nodes generated: 28
# state = [['*', '8', '1'], ['2', '4', '3'], ['7', '6', '5']]; f(n) = 45; g(n) = 10; h(n) = 35; p(n) = 8; s(n) = 9; Number of nodes generated: 30
# state = [['2', '8', '1'], ['4', '3', '*'], ['7', '6', '5']]; f(n) = 45; g(n) = 9; h(n) = 36; p(n) = 9; s(n) = 9; Number of nodes generated: 31
# state = [['2', '*', '1'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 49; g(n) = 9; h(n) = 40; p(n) = 7; s(n) = 11; Number of nodes generated: 33
# state = [['*', '2', '1'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 49; g(n) = 10; h(n) = 39; p(n) = 6; s(n) = 11; Number of nodes generated: 35
# state = [['2', '1', '*'], ['4', '8', '3'], ['7', '6', '5']]; f(n) = 49; g(n) = 10; h(n) = 39; p(n) = 6; s(n) = 11; Number of nodes generated: 36
# state = [['2', '1', '3'], ['4', '8', '*'], ['7', '6', '5']]; f(n) = 49; g(n) = 11; h(n) = 38; p(n) = 5; s(n) = 11; Number of nodes generated: 37
# state = [['8', '*', '1'], ['2', '4', '3'], ['7', '6', '5']]; f(n) = 51; g(n) = 11; h(n) = 40; p(n) = 7; s(n) = 11; Number of nodes generated: 39
# state = [['8', '1', '*'], ['2', '4', '3'], ['7', '6', '5']]; f(n) = 45; g(n) = 12; h(n) = 33; p(n) = 6; s(n) = 9; Number of nodes generated: 41
# state = [['8', '1', '3'], ['2', '4', '*'], ['7', '6', '5']]; f(n) = 45; g(n) = 13; h(n) = 32; p(n) = 5; s(n) = 9; Number of nodes generated: 42
# state = [['8', '1', '3'], ['2', '*', '4'], ['7', '6', '5']]; f(n) = 36; g(n) = 14; h(n) = 22; p(n) = 4; s(n) = 6; Number of nodes generated: 44
# state = [['8', '1', '3'], ['*', '2', '4'], ['7', '6', '5']]; f(n) = 33; g(n) = 15; h(n) = 18; p(n) = 3; s(n) = 5; Number of nodes generated: 47
# state = [['*', '1', '3'], ['8', '2', '4'], ['7', '6', '5']]; f(n) = 33; g(n) = 16; h(n) = 17; p(n) = 2; s(n) = 5; Number of nodes generated: 49
# state = [['1', '*', '3'], ['8', '2', '4'], ['7', '6', '5']]; f(n) = 27; g(n) = 17; h(n) = 10; p(n) = 1; s(n) = 3; Number of nodes generated: 50
# state = [['1', '2', '3'], ['8', '*', '4'], ['7', '6', '5']]; f(n) = 18; g(n) = 18; h(n) = 0; p(n) = 0; s(n) = 0; Number of nodes generated: 52
#
# Summary for A* using NilssonSequenceScore
# +----------------------------------------------------------+
# Nodes generated: 52; Unique nodes generated: 52; Nodes expanded: 28
# Open List: 24; Closed List: 29
#
# Sequence of states from start to goal
# +----------------------------------------------------------+
# Moves 0 to 9
# 2 1 6    2 1 6    2 1 *    2 * 1    2 8 1    2 8 1    2 8 1    2 8 1    2 8 1    2 8 1
# 4 * 8 -> 4 8 * -> 4 8 6 -> 4 8 6 -> 4 * 6 -> 4 6 * -> 4 6 3 -> 4 6 3 -> 4 * 3 -> * 4 3
# 7 5 3    7 5 3    7 5 3    7 5 3    7 5 3    7 5 3    7 5 *    7 * 5    7 6 5    7 6 5
# Moves 10 to 18
# * 8 1    8 * 1    8 1 *    8 1 3    8 1 3    8 1 3    * 1 3    1 * 3    1 2 3
# 2 4 3 -> 2 4 3 -> 2 4 3 -> 2 4 * -> 2 * 4 -> * 2 4 -> 8 2 4 -> 8 2 4 -> 8 * 4
# 7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5    7 6 5
